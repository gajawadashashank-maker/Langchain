# %%
# !pip install langchain-openai
# Out:
# ^C

# %%
from langchain_openai import ChatOpenAI  
import os  
import httpx  
client = httpx.Client(verify=False) 
llm = ChatOpenAI( 
base_url="https://genailab.tcs.in",
model = "azure_ai/genailab-maas-DeepSeek-V3-0324", 
api_key="sk-rbzE3xKfBTDiDz-hV8ERAg", # Will be provided during event.  And this key is for 
http_client = client 
) 
response = llm.invoke("Hi") 
print(response)
# Out:
# content='Hello! 😊 How can I assist you today?' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 6, 'total_tokens': 18, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'azure_ai/DeepSeek-V3-0324', 'system_fingerprint': None, 'id': '709a9594d8204331a97fc9344963d832', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--3b80914d-1f87-42e1-859d-d21650ada3dd-0' usage_metadata={'input_tokens': 6, 'output_tokens': 12, 'total_tokens': 18, 'input_token_details': {}, 'output_token_details': {}}

# %%
print(1)
# Out:
# 1
